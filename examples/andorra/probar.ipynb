# %%
import geopandas as gpd

# %%
level_of_service = gpd.read_file("level_of_service_streets.gpkg")

# %%
level_of_service.columns
# Out:
# Index(['u', 'v', 'key', 'osmid_group_v', 'osmid_group_u_right', 'lanes',
#        'changed_u', 'maxspeed', 'bridge', 'width', 'oneway', 'osmid_group_u',
#        'osmid', 'access', 'junction', 'changed_v', 'area', 'name',
#        'osmid_group_v_right', 'service', 'reversed', 'ref', 'tunnel',
#        'highway', 'length', 'accessibility', 'geometry'],
#       dtype='object')

# %%
level_of_service.plot(column = "accessibility")
# Out:
# <Axes: >

# %%
streets = gpd.read_file("streets.gpkg")

# %%
streets.columns
# Out:
# Index(['u', 'v', 'key', 'osmid_group_v', 'osmid_group_u_right', 'lanes',
#        'changed_u', 'maxspeed', 'bridge', 'width', 'oneway', 'osmid_group_u',
#        'osmid', 'access', 'junction', 'changed_v', 'area', 'name',
#        'osmid_group_v_right', 'service', 'reversed', 'ref', 'tunnel',
#        'highway', 'length', 'geometry'],
#       dtype='object')

# %%
streets.plot()
# Out:
# <Axes: >

# %%
population = gpd.read_file("population.gpkg")

# %%
population.columns
# Out:
# Index(['h3_cell', 'accessibility', 'population', 'geometry'], dtype='object')

# %%
population.plot(column = "accessibility")
# Out:
# <Axes: >

# %%
print(population.iloc[20].geometry)
# Out:
# POLYGON ((379951.67453684757 4705547.881751348, 379936.7751435308 4705473.154056729, 379991.5265596118 4705427.217851571, 380061.1777793501 4705456.009769375, 380076.0770436683 4705530.738017923, 380021.3252172443 4705576.67379473, 379951.67453684757 4705547.881751348))
