# %% [markdown]
# # 🏫 Accessibility to Schools & Active Mobility Analysis — Andorra
# ---
#
# ## 📖 Overview
# This notebook evaluates the accessibility of schools within **Andorra**. By cross-referencing street network connectivity with population density, we quantify the reach of educational infrastructure.
#
# The primary goal is to **assess the maximum potential of active mobility modes** (walking and cycling) compared to motorized transport.
#
# ---
#
# ## 🚀 Key Features
#
# *   📍 **Automated POI Discovery** | Fetches city boundaries and school locations directly from OpenStreetMap (OSM).
# *   🚲 **Multi-Modal Isochrones** | Generates reachability zones based on specific thresholds:
#     *   **Walking:** 1,000m
#     *   **Biking:** 2,500m
#     *   **Motorized:** 10,000m
# *   🕸️ **Network Graphing** | Builds and simplifies OSM street graphs to ensure high-accuracy routing.
# *   👥 **Demographic Overlay** | Integrates **WorldPop** raster data (filtered for under-18 demographics) to calculate the actual number of residents served.
# *   ⬢ **Spatial Indexing** | Utilizes **Uber's H3 Hexagonal Grids** for standardized spatial analysis and data normalization.
# *   📊 **Rich Outputs** | Produces interactive Folium maps, GIS-ready GeoPackages (GPKG), and statistical CSV summaries.
#
# ---
#
# ## 🛠️ Technical Requirements
#
# To run this analysis successfully, ensure your environment includes:
#
# > **Core Libraries:** `UrbanAccessAnalyzer`, `osmnx`, `geopandas`
# > **System Tools:** `osmium-tool` (required for street network processing)
# > **Data Sources:** OpenStreetMap (via Overpass API) and WorldPop
#
# ---
#
# *Prepared for use in Google Colab or local Jupyter instances.*
#
# ***

# %%
# If using colab
# Takes around 2-3 min

# !pip install matplotlib mapclassify folium
# !apt-get install -y osmium-tool
# !pip install "UrbanAccessAnalyzer[osm,plot,h3] @ git+https://github.com/CityScope/UrbanAccessAnalyzer.git@v1.0.0"

# Restart notebook after installing this if needed

# %%
import os
from datetime import datetime, date, timedelta, time
import pandas as pd
import geopandas as gpd
from shapely import wkt
import os

import osmnx as ox

import matplotlib.pyplot as plt
import folium

import UrbanAccessAnalyzer.isochrones as isochrones
import UrbanAccessAnalyzer.graph_processing as graph_processing
import UrbanAccessAnalyzer.osm as osm
import UrbanAccessAnalyzer.utils as utils
import UrbanAccessAnalyzer.h3_utils as h3_utils
import UrbanAccessAnalyzer.population as population
import UrbanAccessAnalyzer.poi_utils as poi_utils
import UrbanAccessAnalyzer.plot_helpers as plot_helpers

import zipfile
import numpy as np
import requests
import tempfile

# %% [markdown]
# ## 1 Inputs

# %%
city_name = "Andorra"

# %%
# Download area should be larger than the aoi by 'download_buffer' meters
# It should be max(distance_steps) to avoid border issues 
# Using a smaller value as we only consider one school district
download_buffer = 0

# Distance steps for the isochrones (points in the street network reachable in x distance from any point of interest)
distance_steps = [1000,3000,5000,10000] 

# Value to assign to every distance step
# We consider 1000m is reachable walking and 2500m biking, 10km would be by car and more would be unreachable
accessibility_values = [1000.0, 3000.0, 5000.0, 10000.0] 

min_edge_length = 30 # Simplify street graph to avoid edges of less than 'min_edge_length'

h3_resolution = 10 # If you want results in h3 this is the output h3 resolution

kids_only = False # If True the population data is only people under 18 years age

show_maps = True # Maps take time to generate and render

# %% [markdown]
# ### Results folder
#
# Where do you want to save the results?

# %%
results_path = os.path.normpath("output")

# %%
city_filename = utils.sanitize_filename(city_name)
city_results_path = os.path.join(results_path,city_filename)
os.makedirs(results_path,exist_ok=True)
os.makedirs(city_results_path,exist_ok=True)

# %%
poi_path = os.path.normpath(city_results_path+f"/schools.gpkg")
osm_xml_file = os.path.normpath(city_results_path+f"/streets.osm")
streets_graph_path = os.path.normpath(city_results_path+f"/streets.graphml")
streets_path = os.path.normpath(city_results_path+f"/streets.gpkg")
level_of_service_streets_path = os.path.normpath(city_results_path+f"/level_of_service_streets.gpkg")
population_results_path = os.path.normpath(city_results_path+f"/population.gpkg")

# %% [markdown]
# ### Area of interest
# **Area of interest (aoi)**: Polygon. Geographic area where you want to run your analysis.

# %%
aoi = utils.get_city_geometry(city_name)
geo_suggestions = utils.get_geographic_suggestions_from_string(city_name,user_agent="app")
geo_suggestions
# Out:
# {'country_codes': ['AD'], 'subdivision_names': [], 'municipalities': []}

# %% [markdown]
# Use UTM coords and create aoi_download with a buffer of X meters. To avoid boundary effects streets and pois should be downloaded for a larger area.

# %%
aoi = gpd.GeoDataFrame(geometry=[aoi.union_all()],crs=aoi.crs) # Ensure there is only one polygon
aoi = aoi.to_crs(aoi.estimate_utm_crs()) # Convert to utm

aoi_download = aoi.buffer(download_buffer) # Area to do streets and poi requests

# %% [markdown]
# ### Points of interest
#
# **Point of interest (poi):** Point that people want to reach and that serve as the origin of isochrones.
#
# **Isochrone:** All points in the street network that are reachable within a given distance from any point of interest.

# %% [markdown]
# **Option 1:** Openstreetmap data with an overpass api query

# %%
query = """
[out:xml] [timeout:25];
(
    node["amenity"="school"]( {{bbox}});
    way["amenity"="school"]( {{bbox}});
    relation["amenity"="school"]( {{bbox}});
);
(._;>;);
out body;
"""

# %%
# If it fails execute again

# poi = osm.overpass_api_query(query,aoi_download)
# poi.geometry = poi.geometry.centroid
# poi = poi.to_crs(aoi.crs)
# poi.to_file(poi_path)

# %%
# poi = poi.to_crs(aoi.crs)
# poi = poi[poi.geometry.intersects(aoi_download.union_all())]
# poi
from pathlib import Path
poi = gpd.read_file(Path("andorra") / "schools.gpkg")
poi.geometry = poi.geometry.centroid
poi = poi.to_crs(aoi.crs)
poi.to_file(poi_path)
poi
# Out:
#     type            id                                              nodes  \
# 0   node  5.299409e+08                                               None
# 1   node  6.907085e+08                                               None
# 2   node  2.966704e+09                                               None
# 3   node  4.456959e+09                                               None
# 4   node  4.456959e+09                                               None
# 5   node  4.686884e+09                                               None
# 6   node  4.984743e+09                                               None
# 7   node  5.734220e+09                                               None
# 8   node  8.427040e+09                                               None
# 9    way  6.798310e+08  [6365392356, 9665415608, 6365392360, 636539235...
# 10   way  7.137961e+08  [6711004283, 6711004284, 6711013685, 671101368...
# 11   way  9.980083e+08  [9214972751, 9214972750, 9706982198, 970698211...
# 12   way  9.994841e+08  [9226884488, 9226884487, 12197364229, 92268844...
# 13   way  1.051803e+09  [9665651083, 9665651084, 9665651085, 966565108...
# 14   way  1.052203e+09  [9669726559, 9669726560, 9669726561, 966972656...
# 15   way  1.052205e+09  [9669748226, 9669748238, 9669748286, 966974824...
# 16   way  1.056156e+09  [9704673486, 9704673539, 9704673492, 970467349...
# 17   way  1.056578e+09  [9708672603, 9708672602, 9708672606, 970867261...
# 18   way  1.057801e+09  [9719749644, 9719749656, 9719749657, 971974965...
# 19   way  1.058237e+09  [9723996934, 9723996947, 9723996948, 972399694...
# 20   way  1.058442e+09  [9725933903, 9725933904, 3171462878, 972593390...
# 21   way  1.058442e+09  [9725934157, 9725934168, 9725934169, 972593417...
# 22   way  1.059178e+09  [9731875459, 9731875460, 9731875461, 973187546...
# 23   way  1.059804e+09  [9737154055, 9737154054, 9737154053, 973715405...
# 24   way  1.144344e+09  [10651650519, 10651650520, 10651650521, 106516...
# 25   way  1.174086e+09  [10909384494, 10909384493, 10909384492, 109093...
# 26  None           NaN                                               None
# 27  None           NaN                                               None
#
#    amenity  check_date                                               name  \
# 0   school        None                                               None
# 1   school  2026-01-18                         Centre de Autoaprenentatge
# 2   school        None        Centre d'autoaprenentatge de llengua Catalá
# 3   school        None                                               None
# 4   school        None                                               None
# 5   school        None                        Centre de Formació d'adults
# 6   school        None                                               None
# 7   school        None                        Escola bresol Prada Casadet
# 8   school        None                             Col·legi Sant Ermengol
# 9   school        None                        Agora International Andorra
# 10  school        None     Escola Andorrana de Segona Ensenyança d'Encamp
# 11  school        None                          British College d'Andorra
# 12  school        None                                Lycée Comte de Foix
# 13  school        None                   Escola d'Art Floral i Jardineria
# 14  school        None  Escola Andorrana de Maternal i de 1a Ensenyanç...
# 15  school        None  Escola Francesa de Maternal i de 1a Ensenyança...
# 16  school        None                                Lycée Comte de Foix
# 17  school        None                Escola Andorrana d'Andorra la Vella
# 18  school        None         Escola Andorrana de 2a Ensenyança d'Ordino
# 19  school        None  Escola Germans de Riba (Andorrana de 1a Enseny...
# 20  school        None                             Col·legi Sant Ermengol
# 21  school        None                    Col·legi Espanyol Maria Moliner
# 22  school        None                             Escola Sagrada Familia
# 23  school        None  Col·legi de la Peletera (Escola Francesa d'Esc...
# 24  school        None                                               None
# 25  school        None                                   Escola Andorrana
# 26  school        None                        Escola Andorrana de Canillo
# 27  school        None                         Escola Francesa de Canillo
#
#                                               name:ca  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                         Centre de Formació d'adults
# 6                                                None
# 7                                                None
# 8                              Col·legi Sant Ermengol
# 9                                                None
# 10     Escola Andorrana de Segona Ensenyança d'Encamp
# 11                                               None
# 12                                               None
# 13                   Escola d'Art Floral i Jardineria
# 14  Escola Andorrana de Maternal i de 1a Ensenyanç...
# 15  Escola Francesa de Maternal i de 1a Ensenyança...
# 16                                               None
# 17                Escola Andorrana d'Andorra la Vella
# 18         Escola Andorrana de 2a Ensenyança d'Ordino
# 19  Escola Germans de Riba (Andorrana de 1a Enseny...
# 20                             Col·legi Sant Ermengol
# 21                    Col·legi Espanyol Maria Moliner
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
#
#                         website   wikidata                  wikipedia  \
# 0                          None       None                       None
# 1                          None       None                       None
# 2                          None       None                       None
# 3                          None       None                       None
# 4                          None       None                       None
# 5                          None       None                       None
# 6                          None       None                       None
# 7                          None       None                       None
# 8   http://see.xena.ad/sterme/?  Q11914777  ca:Col·legi Sant Ermengol
# 9                          None       None                       None
# 10                         None       None                       None
# 11                         None       None                       None
# 12                         None   Q3268636                       None
# 13                         None       None                       None
# 14                         None       None                       None
# 15                         None       None                       None
# 16                         None       None                       None
# 17                         None       None                       None
# 18                         None       None                       None
# 19                         None       None                       None
# 20                         None       None                       None
# 21                         None       None                       None
# 22                         None       None                       None
# 23                         None       None                       None
# 24                         None       None                       None
# 25                         None       None                       None
# 26                         None       None                       None
# 27                         None       None                       None
#
#     addr:city addr:postcode                   addr:street  \
# 0        None          None                          None
# 1        None          None                          None
# 2        None          None                          None
# 3        None          None                          None
# 4        None          None                          None
# 5        None          None                          None
# 6        None          None                          None
# 7        None          None                          None
# 8        None          None                          None
# 9   L'ALDOSA,         AD400  Poliesportiu de L'Aldosa s/n
# 10       None          None                          None
# 11       None          None                          None
# 12       None          None                          None
# 13       None          None                          None
# 14       None          None                          None
# 15       None          None                          None
# 16       None          None                          None
# 17       None          None                          None
# 18       None          None                          None
# 19       None          None                          None
# 20       None          None                          None
# 21       None          None                          None
# 22       None          None                          None
# 23       None          None                          None
# 24       None          None                          None
# 25       None          None                          None
# 26       None          None                          None
# 27       None          None                          None
#
#            building:levels                        geometry
# 0                     None  POINT (379878.278 4712574.813)
# 1                     None  POINT (396095.463 4710903.067)
# 2                     None  POINT (378463.533 4711431.782)
# 3                     None  POINT (383286.742 4710209.654)
# 4                     None   POINT (382643.633 4709825.17)
# 5                     None   POINT (375831.813 4703751.09)
# 6                     None  POINT (383526.382 4710338.638)
# 7                     None  POINT (378680.481 4706954.529)
# 8                     None  POINT (379376.736 4707725.562)
# 9   all age private school  POINT (378672.603 4711270.078)
# 10                    None  POINT (382635.946 4709865.287)
# 11                    None  POINT (379029.439 4706414.174)
# 12                    None  POINT (378013.723 4706774.889)
# 13                    None  POINT (378659.596 4711667.236)
# 14                    None  POINT (378018.536 4711214.201)
# 15                    None  POINT (378007.886 4711327.066)
# 16                    None  POINT (378042.314 4707010.559)
# 17                    None  POINT (376967.717 4706003.136)
# 18                    None   POINT (379310.15 4712258.063)
# 19                    None  POINT (379868.655 4712616.488)
# 20                    None   POINT (379368.46 4707694.841)
# 21                    None   POINT (379705.068 4707665.29)
# 22                    None  POINT (380107.264 4707507.052)
# 23                    None  POINT (380232.729 4707610.976)
# 24                    None  POINT (383524.318 4710336.652)
# 25                    None  POINT (376131.664 4702505.536)
# 26                    None  POINT (384922.022 4713771.635)
# 27                    None  POINT (384944.975 4713780.511)

# %% [markdown]
# Map of your aoi, the download area (aoi_buffer) and the pois

# %%
m = None
if show_maps:
    m = aoi_download.explore(
        color="red",
        fill=False,
        style_kwds={"weight": 4, "dashArray": "5,5", "opacity": 1.0},
    )

    m = plot_helpers.general_map(
        m=m,
        aoi=aoi,
        pois=poi,
    )
    
# m

# %% [markdown]
# ## 2 Street graph

# %% [markdown]
# ### 2.1 Download Andorra PBF and convert to OSM
#
# - Downloads the Andorra PBF directly from Geofabrik (~3MB)
# - Applies tag filter and crops to AOI using osmium

# %% [markdown]
# #### OSMIUM
#
# To download the street network needed for the study online, the **osmium** tool is used.
# It is only available for **Linux** and **Mac** (it works in Google Colab too).
#
# To install, you can either:
#
# - Visit [osmium-tool website](https://osmcode.org/osmium-tool/)
# - Or run the command:
# ```bash
#   sudo apt-get install -y osmium-tool
# ````
#
# Make sure it is added to your `PATH`.
#
# On **Windows**, you can use **conda-forge** to install it.
#
# ```bash
#   conda install -c conda-forge osmium-tool
# ````
# ---
#
# To avoid using **osmium**, you can manually download the data:
#
# 1. Go to [OpenStreetMap Export](https://www.openstreetmap.org/export#map=14/40.23633/-3.76084)
# 2. Select the bounding box containing your area of interest.
# 3. Click **Export**.
# 4. Copy the `.osm` file that is downloaded to your project folder.
# 5. Set the variable `osm_xml_file` to the path where the `.osm` file is located.

# %%
# WARNING: Execute only if osmium is installed

# Download Andorra PBF directly from Geofabrik
# The auto-detection in geofabrik_to_osm fails for Andorra because the
# Geofabrik boundary polygon doesn't perfectly contain the OSM-geocoded
# Andorra polygon (tiny boundary mismatch). So we download it explicitly.

andorra_pbf_url = "https://download.geofabrik.de/europe/andorra-latest.osm.pbf"
andorra_pbf_path = os.path.join(results_path, "andorra-latest.osm.pbf")

if not os.path.isfile(andorra_pbf_path):
    print(f"Downloading Andorra PBF from {andorra_pbf_url}...")
    resp = requests.get(andorra_pbf_url, stream=True)
    resp.raise_for_status()
    with open(andorra_pbf_path, "wb") as f:
        for chunk in resp.iter_content(chunk_size=8192):
            f.write(chunk)
    print(f"Downloaded to {andorra_pbf_path}")
else:
    print(f"File '{andorra_pbf_path}' already exists. Skipping download.")

# Select what type of street network you want to load
network_filter = osm.osmium_network_filter("walk+bike+primary")

# Convert the downloaded PBF to filtered OSM XML
osm.geofabrik_to_osm(
    osm_xml_file,
    input_file=andorra_pbf_path,
    aoi=aoi_download,
    osmium_filter_args=network_filter,
    overwrite=False
)
# Out:
# File 'output/andorra-latest.osm.pbf' already exists. Skipping download.
# File 'output/andorra/streets.osm' already exists. Skipping conversion.
# 'output/andorra/streets.osm'

# %%
# Only if you downloaded the street network externally
# osm_xml_file = 'path/to/file.osm'

# %% [markdown]
# ### 2.2 Load to osmnx
#
# This way the street network is a networkx graph

# %%
# Load
G = ox.graph_from_xml(osm_xml_file)
# Project geometry coordinates to UTM system to allow euclidean meassurements in meters (sorry americans)
G = ox.project_graph(G,to_crs=aoi.estimate_utm_crs())
# Save the graph in graphml format to avoid the slow loading process
ox.save_graphml(G,streets_graph_path)

# %% [markdown]
# ### 2.3 Simplify graph
#
# Edges with length smaler than X meters are deleted and its nodes merged

# %%
G = graph_processing.simplify_graph(G,min_edge_length=min_edge_length,min_edge_separation=min_edge_length*2,undirected=True)
# Save the result in graphml format
ox.save_graphml(G,streets_graph_path)

street_edges = ox.graph_to_gdfs(G,nodes=False)
street_edges = street_edges.to_crs(aoi.crs)
street_edges.to_file(streets_path)

# %% [markdown]
# # 3 Points of interest

# %% [markdown]
# ### 3.1 Add Points of interest to graph

# %%
G, osmids = graph_processing.add_points_to_graph(
    poi,
    G,
    max_dist=100+min_edge_length, # Maximum distance from point to graph edge to project the point
    min_edge_length=min_edge_length # Minimum edge length after adding the new nodes
)
poi['osmid'] = osmids # Add the ids of the nodes in the graph to points
print(poi["osmid"])
# Out:
# 0        53319484
# 1     13716205461
# 2       277386825
# 3     13716205462
# 4     13716205463
# 5     13716205464
# 6      1933926873
# 7     13716205465
# 8      9725933824
# 9       264502063
# 10    13716205466
# 11    13716205467
# 12    13716205468
# 13    13716205469
# 14     2748482573
# 15      316949605
# 16    13716205470
# 17    13716205471
# 18    13716205472
# 19     9724022832
# 20    13716205473
# 21    13716205474
# 22    13716205475
# 23    12206912993
# 24     1933926873
# 25     5150459999
# 26    13716205476
# 27    13716205476
# Name: osmid, dtype: int64

# %% [markdown]
# ## 4 Compute isochrones

# %% [markdown]
# ### 4.1 Isochrones

# %%
accessiblity_graph = isochrones.graph(
    G,
    poi,
    distance_steps, # If poi_quality_col is None it could be a list of distances
    poi_quality_col = None, # If all points have the same quality this could be None
    accessibility_values = accessibility_values, # could be None and it will set to the sorted unique values of the matrix
    min_edge_length = min_edge_length # Do not add new nodes if there will be an edge with less than this length
)
# Save edges as gpkg
accessibility_nodes, accessibility_edges = ox.graph_to_gdfs(accessiblity_graph)
accessibility_edges.to_file(level_of_service_streets_path)
print(level_of_service_streets_path)
# Out:
# 100%|██████████| 4/4 [00:03<00:00,  1.19it/s]
# /home/xabi9/Documents/Sources/UrbanAccessAnalyzer/UrbanAccessAnalyzer/isochrones.py:345: UserWarning: No nodes have attribute remaining_dist. Probably no isochrones have been generated.
#   warnings.warn(
# output/andorra/level_of_service_streets.gpkg

# %% [markdown]
# ### 4.2 Convert to H3

# %%
access_h3_df = h3_utils.from_gdf(
    accessibility_edges,
    resolution=h3_resolution,
    columns=['accessibility'],
    value_order=accessibility_values,
    contain="overlap",
    method="min",
    buffer=10
)

access_h3_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 access_h3_df = h3_utils.from_gdf(
#       2     accessibility_edges,
#       3     resolution=h3_resolution,
#       4     columns=['accessibility'],
#
# File ~/Documents/Sources/UrbanAccessAnalyzer/UrbanAccessAnalyzer/h3_utils.py:534, in from_gdf(gdf, resolution, columns, value_order, buffer, contain, method)
#     488 """
#     489 Rasterize a GeoDataFrame directly into aggregated H3 cells.
#     490
#    (...)    524     Aggregated values indexed by H3 cell.
#     525 """
#     527 h3_df = cells_in_geometry(
#     528     gdf,
#     529     resolution=resolution,
#     530     buffer=buffer,
#     531     contain=contain,
#     532 )
# --> 534 return aggregate(
#     535     h3_df,
#     536     columns=columns,
#     537     value_order=value_order,
#     538     method=method,
#     539 )
#
# File ~/Documents/Sources/UrbanAccessAnalyzer/UrbanAccessAnalyzer/h3_utils.py:308, in aggregate(h3_df, columns, value_order, method, h3_column)
#     305     h3_df["idx"] = h3_df.index
#     306     columns = ["idx"]
# --> 308 h3_df = h3_df.dropna(
#     309     how="all",
#     310     subset=columns,
#     311 )
#     313 # Normalize value_order into dict form
#     314 if not isinstance(value_order, dict):
#
# File ~/Documents/Sources/UrbanAccessAnalyzer/.venv/lib/python3.12/site-packages/pandas/core/frame.py:6692, in DataFrame.dropna(self, axis, how, thresh, subset, inplace, ignore_index)
#    6688             ax = self._get_axis(agg_axis)
#    6689             indices = ax.get_indexer_for(subset)
#    6690             check = indices == -1
#    6691             if check.any():
# -> 6692                 raise KeyError(np.array(subset)[check].tolist())
#    6693             agg_obj = self.take(indices, axis=agg_axis)
#    6694
#    6695         if thresh is not lib.no_default:
#
# KeyError: ['accessibility']

# %%
access_h3_df.shape
# Out:
# (0, 1)

# %% [markdown]
# See everything on a map

# %%
m = None
if show_maps:
    m = plot_helpers.general_map(
        aoi=aoi,
        pois=poi,
        gdfs=[access_h3_df,accessibility_edges],
        cmap="managua",
        column="accessibility"
    )
    m.save(city_results_path+"/access_map.html")
m
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 10
#       6         gdfs=[access_h3_df,accessibility_edges],
#       7         cmap="managua",
#       8         column="accessibility"
#       9     )
# ---> 10     m.save(city_results_path+"/access_map.html")
#      11 m
#
# File ~/Documents/Sources/UrbanAccessAnalyzer/.venv/lib/python3.12/site-packages/branca/element.py:232, in Element.save(self, outfile, close_file, **kwargs)
#     229     fid = outfile
#     231 root = self.get_root()
# --> 232 html = root.render(**kwargs)
#     233 fid.write(html.encode("utf8"))
#     234 if close_file:
#
# File ~/Documents/Sources/UrbanAccessAnalyzer/.venv/lib/python3.12/site-packages/branca/element.py:409, in Figure.render(self, **kwargs)
#     407 """Renders the HTML representation of the element."""
#     408 for name, child in self._children.items():
# --> 409     child.render(**kwargs)
#     410 return self._template.render(this=self, kwargs=kwargs)
#
# File ~/Documents/Sources/UrbanAccessAnalyzer/.venv/lib/python3.12/site-packages/folium/elements.py:46, in JSCSSMixin.render(self, **kwargs)
#      43 for name, url in self.default_css:
#      44     figure.header.add_child(CssLink(url), name=name)
# ---> 46 super().render(**kwargs)
#
# File ~/Documents/Sources/UrbanAccessAnalyzer/.venv/lib/python3.12/site-packages/folium/map.py:73, in Class.render(self, **kwargs)
#      64     # A bit weird. I tried adding IncludeStatement directly to both
#      65     # figure and script, but failed. So we render this ourself.
#      66     figure.script.add_child(
#      67         Element(stmt._template.render(this=stmt, kwargs=self.includes)),
#      68         # make sure each class include gets rendered only once
#    (...)     71         index=-1,
#      72     )
# ---> 73 super().render(**kwargs)
#
# File ~/Documents/Sources/UrbanAccessAnalyzer/.venv/lib/python3.12/site-packages/branca/element.py:740, in MacroElement.render(self, **kwargs)
#     737     figure.script.add_child(Element(script(self, kwargs)), name=self.get_name())
#     739 for name, element in self._children.items():
# --> 740     element.render(**kwargs)
#
# File ~/Documents/Sources/UrbanAccessAnalyzer/.venv/lib/python3.12/site-packages/branca/colormap.py:126, in ColorMap.render(self, **kwargs)
#     122 """Renders the HTML representation of the element."""
#     123 self.color_domain = [
#     124     float(self.vmin + (self.vmax - self.vmin) * k / 499.0) for k in range(500)
#     125 ]
# --> 126 self.color_range = [self.__call__(x) for x in self.color_domain]
#     128 # sanitize possible numpy floats to native python floats
#     129 self.index = [float(i) for i in self.index]
#
# File ~/Documents/Sources/UrbanAccessAnalyzer/.venv/lib/python3.12/site-packages/branca/colormap.py:184, in ColorMap.__call__(self, x)
#     180 def __call__(self, x: float) -> str:
#     181     """Provides the color corresponding to value `x` in the
#     182     form of a string of hexadecimal values "#RRGGBBAA".
#     183     """
# --> 184     return self.rgba_hex_str(x)
#
# File ~/Documents/Sources/UrbanAccessAnalyzer/.venv/lib/python3.12/site-packages/branca/colormap.py:178, in ColorMap.rgba_hex_str(self, x)
#     174 def rgba_hex_str(self, x: float) -> str:
#     175     """Provides the color corresponding to value `x` in the
#     176     form of a string of hexadecimal values "#RRGGBBAA".
#     177     """
# --> 178     return "#%02x%02x%02x%02x" % self.rgba_bytes_tuple(x)
#
# File ~/Documents/Sources/UrbanAccessAnalyzer/.venv/lib/python3.12/site-packages/branca/colormap.py:160, in ColorMap.rgba_bytes_tuple(self, x)
#     156 def rgba_bytes_tuple(self, x: float) -> TypeRGBAInts:
#     157     """Provides the color corresponding to value `x` in the
#     158     form of a tuple (R,G,B,A) with int values between 0 and 255.
#     159     """
# --> 160     return tuple(_color_float_to_int(u) for u in self.rgba_floats_tuple(x))
#
# File ~/Documents/Sources/UrbanAccessAnalyzer/.venv/lib/python3.12/site-packages/branca/colormap.py:325, in LinearColormap.rgba_floats_tuple(self, x)
#     323     p = 1.0
#     324 else:
# --> 325     raise ValueError("Thresholds are not sorted.")
#     327 return tuple(  # type: ignore
#     328     (1.0 - p) * self.colors[i - 1][j] + p * self.colors[i][j] for j in range(4)
#     329 )
#
# ValueError: Thresholds are not sorted.

# %% [markdown]
# ## 5 Population

# %% [markdown]
# ### 5.1 Download Worldpop tif file
#
# - One file for every country
# - 100m pixel size
# - tif format
# - available from 2000 to 2030
# - gender and age

# %%
if kids_only:
    population_file = population.download_worldpop_population(
        aoi_download,
        2025,
        folder=results_path,
        resolution="100m",
        dataset="age_structures",
        subset="U18"
    )
else:
    population_file = population.download_worldpop_population(
        aoi_download,
        2025,
        folder=results_path,
        resolution="100m",
    )
# Out:
# Raster population path output/and_pop_2025_CN_100m_R2025A_v1.tif exists. Skipping download...

# %%
# If downloaded the U18 file unzip it
if ".zip" in population_file:
    zip_path = population_file

    # Extract to the same directory as the zip file
    extract_dir = os.path.splitext(zip_path)[0]
    os.makedirs(extract_dir, exist_ok=True)

    # Decompress the zip file
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)

    # Find the .tif file that contains '_T_'
    for file_name in os.listdir(extract_dir):
        if file_name.lower().endswith('.tif') and '_T_' in file_name:
            population_file = os.path.join(extract_dir, file_name)
            break
    else:
        raise FileNotFoundError("No .tif file containing '_T_' found in the zip archive.")

# %%
pop_h3_df = h3_utils.from_raster(population_file,aoi=aoi_download,resolution=h3_resolution)
pop_h3_df = pop_h3_df.rename(columns={'value':'population'})

# %% [markdown]
# ### 5.2 Assign level of service to each population cell

# %%
results_h3_df = access_h3_df.merge(pop_h3_df,left_index=True,right_index=True,how='outer')
results_h3_df = h3_utils.to_gdf(results_h3_df).to_crs(aoi.crs)
results_h3_df = results_h3_df[results_h3_df.intersects(aoi.union_all())]
results_h3_df.to_file(population_results_path)
results_h3_df
# Out:
#                 accessibility  population  \
# h3_cell
# 8a3962200807fff           NaN    0.061686
# 8a3962200817fff           NaN    0.710272
# 8a3962200827fff           NaN    0.057966
# 8a396220082ffff           NaN    0.019555
# 8a3962200837fff           NaN    6.084394
# ...                       ...         ...
# 8a39623ae25ffff           NaN    0.009009
# 8a39623ae2effff           NaN    0.000015
# 8a39623ae36ffff           NaN    0.009551
# 8a39623ae96ffff           NaN    0.002890
# 8a39623aea4ffff           NaN    0.039204
#
#                                                           geometry
# h3_cell
# 8a3962200807fff  POLYGON ((386036.561 4709777.709, 386021.67 47...
# 8a3962200817fff  POLYGON ((385951.991 4709674.17, 385937.1 4709...
# 8a3962200827fff  POLYGON ((385996.666 4709898.364, 385981.774 4...
# 8a396220082ffff  POLYGON ((386121.132 4709881.249, 386106.24 47...
# 8a3962200837fff  POLYGON ((385912.096 4709794.825, 385897.205 4...
# ...                                                            ...
# 8a39623ae25ffff  POLYGON ((373037.28 4709954.15, 373022.374 470...
# 8a39623ae2effff  POLYGON ((372952.778 4709850.681, 372937.872 4...
# 8a39623ae36ffff  POLYGON ((372878.143 4710436.435, 372863.238 4...
# 8a39623ae96ffff  POLYGON ((371729.793 4711400.028, 371714.887 4...
# 8a39623aea4ffff  POLYGON ((372843.295 4710901.598, 372828.389 4...
#
# [6725 rows x 3 columns]

# %%
m = None 
if show_maps:
    pop_gdf_points = results_h3_df.copy()
    pop_gdf_points.geometry = pop_gdf_points.geometry.centroid
    pop_gdf_points = pop_gdf_points.dropna(subset=['population'])
    pop_gdf_points = pop_gdf_points[pop_gdf_points['population'] > 1]
    m = plot_helpers.general_map(
        aoi=aoi,
        pois=poi,
        gdfs=[pop_gdf_points],
        cmap="managua",
        column="accessibility",
        size_column="population"
    )
    m.save(city_results_path+"/population_map.html")
m
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[83], line 7
#       3     pop_gdf_points = results_h3_df.copy()
#       4     pop_gdf_points.geometry = pop_gdf_points.geometry.centroid
#       5     pop_gdf_points = pop_gdf_points.dropna(subset=['population'])
#       6     pop_gdf_points = pop_gdf_points[pop_gdf_points['population'] > 1]
# ----> 7     m = plot_helpers.general_map(
#       8         aoi=aoi,
#       9         pois=poi,
#      10         gdfs=[pop_gdf_points],
#
# File ~/Documents/Sources/UrbanAccessAnalyzer/UrbanAccessAnalyzer/plot_helpers.py:257, in general_map(m, aoi, pois, gdfs, poi_column, poi_color, poi_cmap, poi_vmin, poi_vmax, poi_opacity, column, color, cmap, vmin, vmax, opacity, size_column, zoom_start)
#     247 style_fn = lambda feature: {
#     248     "radius": feature["properties"]["__radius"],
#     249     "color": None,        # no border
#    (...)    252     "opacity": 1.0,       # stroke opacity (irrelevant here)
#     253 }
#     255 if is_thematic(points, column, cmap):
#     256     # Thematic coloring with variable size
# --> 257     m = points.explore(
#     258         m=m,
#     259         column=column,
#     260         cmap=cmap,
#     261         vmin=vmin,
#     262         vmax=vmax,
#     263         legend=legend,
#     264         marker_type="circle_marker",
#     265         style_kwds={"style_function": style_fn},  # dynamic radius
#     266     )
#     267     legend = False
#     268 else:
#     269     # Fixed color with variable size
#
# File ~/Documents/Sources/UrbanAccessAnalyzer/.venv/lib/python3.12/site-packages/geopandas/geodataframe.py:2479, in GeoDataFrame.explore(self, *args, **kwargs)
#    2477 @doc(_explore)
#    2478 def explore(self, *args, **kwargs) -> folium.Map:
# -> 2479     return _explore(self, *args, **kwargs)
#
# File ~/Documents/Sources/UrbanAccessAnalyzer/.venv/lib/python3.12/site-packages/geopandas/explore.py:449, in _explore(df, column, cmap, color, m, tiles, attr, tooltip, popup, highlight, categorical, legend, scheme, k, vmin, vmax, width, height, categories, classification_kwds, control_scale, marker_type, marker_kwds, style_kwds, highlight_kwds, missing_kwds, tooltip_kwds, popup_kwds, legend_kwds, map_kwds, **kwargs)
#     447 # colormap exists in matplotlib
#     448 if cmap in plt.colormaps():
# --> 449     color = np.apply_along_axis(
#     450         colors.to_hex,
#     451         1,
#     452         _colormap_helper(cmap, n_resample=N, idx=cat.codes),
#     453     )
#     454     legend_colors = np.apply_along_axis(
#     455         colors.to_hex, 1, _colormap_helper(cmap, n_resample=N, idx=range(N))
#     456     )
#     458 # colormap is matplotlib.Colormap
#
# File ~/Documents/Sources/UrbanAccessAnalyzer/.venv/lib/python3.12/site-packages/numpy/lib/_shape_base_impl.py:372, in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     369 arr = conv[0]
#     371 nd = arr.ndim
# --> 372 axis = normalize_axis_index(axis, nd)
#     374 # arr, with the iteration axis at the end
#     375 in_dims = list(range(nd))
#
# AxisError: axis 1 is out of bounds for array of dimension 0

# %% [markdown]
# ## Statistics

# %%
stats_df = results_h3_df.groupby('accessibility', as_index=False)['population'].sum()
total_population = stats_df['population'].sum()
stats_df = pd.concat([stats_df, pd.DataFrame([{'accessibility': 'total population', 'population': total_population}])], ignore_index=True)
stats_df['population %'] = (stats_df['population'] * 100 / total_population).round(2)
stats_df['population'] = stats_df['population'].round(0).astype(int)
stats_df.to_csv(city_results_path + "/stats.csv")
stats_df
# Out:
#       accessibility  population  population %
# 0  total population           0           NaN

# %%
# !zip -r /content/output.zip "{results_path}" # For colab. Export the output folder as zip.

# %% [markdown]
# Important files:
#
# - streets.gpkg Has the street geometry as lines (all streets)
# - accessibility.gpkg Has the street geometry as lines with the accessibility score (only streets with score > 0)
# - population.gpkg Is a grid with population and level of service
# - stats.csv Population statistics
