# %%
import geopandas as gpd
from pathlib import Path

# %%
current_dir = Path.cwd()

# %%
parks = gpd.read_file(current_dir / "population.gpkg")

# %%
parks.plot(column = "accessibility")

# %%
parks["accessibility"].unique()
# Out:
# array(['0.889', '0.778', '1.0', '0.667', None, '0.556', '0.444', '0.333',
#        '0.222', '0.111'], dtype=object)
