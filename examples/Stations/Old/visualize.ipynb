# %%
import geopandas as gpd
from pathlib import Path

# %%
current_dir = Path().cwd()

# %%
output_dir = current_dir / "output"

# %%
file = gpd.read_file(output_dir / "stations_N100_W0.7_POP80_LAM0.3_access.geojson")

# %%
file.columns
# Out:
# Index(['h3_cell', 'accessibility', 'geometry'], dtype='object')

# %%
file.plot(column="accessibility", legend=True)
