# %%
import geopandas as gpd
from pathlib import Path

# %%
current_dir = Path.cwd()

# %%
file = gpd.read_file(current_dir / "population.gpkg")

# %%
file.shape
# Out:
# (6725, 4)

# %%
print(file.columns)
# Out:
# Index(['h3_cell', 'accessibility', 'population', 'geometry'], dtype='object')

# %%
file.plot()
# Out:
# <Axes: >

# %%
print(file["accessibility"].unique())
# Out:
# [None]
