# %%
import geopandas as gpd
from pathlib import Path

# %%
current_dir = Path.cwd()

# %%
file = gpd.read_file(current_dir / "green_spaces.gpkg")

# %%
file.columns
# Out:
# Index(['geometry'], dtype='object')

# %%
file.plot()
# Out:
# <Axes: >

# %%
pop = gpd.read_file(current_dir / "population.gpkg")

# %%
print(pop.columns)
# Out:
# Index(['h3_cell', 'accessibility', 'population', 'geometry'], dtype='object')

# %%
print(pop["accessibility"].unique())
# Out:
# ['0.889' '0.778' '1.0' '0.667' None '0.556' '0.444' '0.333' '0.222'
#  '0.111']

# %%
pop.plot(column="accessibility", legend=True)
# Out:
# <Axes: >
