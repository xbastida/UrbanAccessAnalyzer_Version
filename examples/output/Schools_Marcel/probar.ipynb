# %%
import geopandas as gpd

# %%
population = gpd.read_file("population.gpkg")

# %%
population.head()
# Out:
#            h3_cell  accessibility  population  \
# 0  8a396220002ffff        10000.0         NaN
# 1  8a3962200057fff        10000.0         NaN
# 2  8a396220005ffff        10000.0         NaN
# 3  8a3962200067fff        10000.0         NaN
# 4  8a396220006ffff        10000.0         NaN
#
#                                             geometry
# 0  POLYGON ((386400.42 4709036.623, 386385.529 47...
# 1  POLYGON ((386564.797 4708898.833, 386549.906 4...
# 2  POLYGON ((386689.275 4708881.709, 386674.384 4...
# 3  POLYGON ((386609.47 4709123.045, 386594.579 47...
# 4  POLYGON ((386733.948 4709105.923, 386719.057 4...

# %%
population["accessibility"].describe()

# %%
population.plot(column="accessibility", legend=True)
# Out:
# <Axes: >
